# %%
#### Program to test making ROI selection for Pad or whateverelse development
#### Created 5/8/23 BWM
# Out:
# Warning: Cannot change to a different GUI toolkit: qt. Using notebook instead.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

x = np.arange(0, 10, 0.005)
y = np.exp(-x/2.) * np.sin(2*np.pi*x)

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_xlim(0, 10)
ax.set_ylim(-1, 1)

plt.show()

# %%
type(ax.transData)
# Out:
# matplotlib.transforms.CompositeGenericTransform

# %%
ax.transData.transform((5, 0))
# Out:
# array([328. , 237.6])

# %%
from roipoly import RoiPoly
im = plt.imread("/Users/benjaminmartin/Documents/MILKTECH/AHS_logo.png")
plt.imshow(im)
my_roi = RoiPoly(color='r')
