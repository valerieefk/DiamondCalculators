# %% [markdown]
# #### A notebook for keck testing and recording. Collected on 06/14/2023 BWM BC YF

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Dac15V =  np.array([1,2,2.5,2.6,2.9,2.95,3,0.5,0.2,0.3,0.35,0.4])
Dac15C = np.array([24598,11950,5617,4358,1829,550,0,28900,31042,32767,32767,3215])
x= Dac15V
y = Dac15C
plt.scatter(y,x, linestyle='-')
plt.show()
